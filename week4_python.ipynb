# %% [markdown]
# <a href="https://colab.research.google.com/github/musabegumm/DSC110/blob/main/week4_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Mussamat')
# Out:
# Hello Mussamat

# %% [markdown]
# # **Variables**: stores information that can be used later on.
#
# In the example below, I'm assigning **"a"** as **"Ireland"** so whenever I code **"a"** it'll print as **"Ireland"** .
#
# ```
# # This is formatted as code
# ```

# %%
a = 'Ireland'

# %%
print(a)
# Out:
# Ireland

# %% [markdown]
# **Counting**: In Python, counting begins from at 0 and continues, unlike in the real wordl, where counting starts at 0.

# %%
print(a[0])
# Out:
# I

# %%
print(a[1])
# Out:
# r

# %%
print(a[2])
# Out:
# e

# %%
print(a[3])
# Out:
# l

# %%
print(a[4])
# Out:
# a

# %%
print(a[5])
# Out:
# n

# %%
print(a[6])
# Out:
# d

# %% [markdown]
# Down below, I added a number and a second number with a colon in the middle. The first number indicates whatever the letter's number is. So 1 is equal to r, : , and 5 is equal to a.

# %%
print(a[1:5])
# Out:
# rela

# %% [markdown]
# Down here is where I assign a letter to a number, so b is 4. I assigned d as b+c = ... .

# %%
b = 4
c = 6
d = b + c

# %%
b + c
# Out:
# 10

# %%
print(d)
# Out:
# 10

# %% [markdown]
# The **"Power"** in Python is where you can calculate the power of a number. For example, : 🔽

# %%
33**5
# Out:
# 39135393

# %% [markdown]
# There are **4 structures** in Python:
#
# 1.   Lists
# 2.   Tuples
# 3.   Sets
# 4.   Dictionaries

# %%
My_Lists=[1, 2, 3, 4, 'a']

# %%
print(My_Lists)
# Out:
# [1, 2, 3, 4, 'a']

# %% [markdown]
# Underneath, I wrote "0:5" which prints all of the integers and strings. If I were to code "0:2" then it would print "[1, 2]"

# %%
print(My_Lists[0:5])
# Out:
# [1, 2, 3, 4, 'a']

# %% [markdown]
# ### **Tuples**: this is especially useful in student IDs, DOBs, it essentially prevents from changing things that cannot be changed.

# %% [markdown]
# Down below, I'm assigning **"My_Tuple"** with **"(1, 3, 5, 7, 'y')"**

# %%
My_Tuple=(1, 3, 5, 7, 'y')

# %%
print(My_Tuple)
# Out:
# (1, 3, 5, 7, 'y')

# %% [markdown]
# Underneath, I printed from My_Tuple and said to print it from "3" which is 7 when we count from 0 and continue.

# %%
print(My_Tuple[3])
# Out:
# 7

# %% [markdown]
# The same goes down below, where I said to print 4 which printed as "y".

# %%
print(My_Tuple[4])
# Out:
# y

# %% [markdown]
# ## **Dictionary**: this is where large infromation can be stored. The information are stored under the main key. So by using key you'd get the values.

# %%
My_Dictionary={
    'Name':"Muniira",
    'Age':'20',
    'Gender':'Female',
    'City':'East Boston'
}

# %%
My_Dictionary['Name']
# Out:
# 'Muniira'

# %%
My_Dictionary['Gender']
# Out:
# 'Female'

# %% [markdown]
# ## **Sets**: this is used for storing multiple things and it allows for no duplicates. For example, 🔽

# %%
My_Set={2, 4, 4, 6, 8, 8}

# %%
print(My_Set)
# Out:
# {8, 2, 4, 6}

# %% [markdown]
# Responding to the code above: as you can see it only wrote the numbers one time even though I write 4 and 8 twice.
